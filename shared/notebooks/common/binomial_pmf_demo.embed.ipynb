# %% [markdown]
# # Notebook: Binomial PMF Profiles
#
# A small notebook block for the binomial PMF at fixed $p=0.3$.
#
# ## W-boson decay example
#
# Example: observe $N$ decays of $W^{\pm}$, the number $n$ of which are
# $W\to\mu\nu$ is a binomial random variable, with $p$ equal to the
# branching ratio.
#
# The plot below shows three cases on one figure: $N=5,20,100$ at fixed
# $p=0.3$.
#
# ``` python
# # The figure is generated by scripts/build_figures.py
# # using N=5,20,100 and p=0.3.
# ```
#
# ![](attachment:../../figures/generated/binomial_pmf_profiles.png){ width="92%"}
